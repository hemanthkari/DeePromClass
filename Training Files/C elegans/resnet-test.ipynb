# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import pandas as pd
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import average_precision_score, precision_recall_fscore_support, accuracy_score, roc_curve, roc_auc_score
import numpy as np
import keras
import matplotlib.pyplot as plt

# %%
SEQ_SIZE = 151

fontsize = 24
train_file_path = "train_data.csv"

df = pd.read_csv(train_file_path)
df = df.sample(frac = 1)

split_data = int(df.shape[0]*0.8)
train_data = df[:split_data]
test_data = df[split_data:]
train_labels = train_data.pop(train_data.columns[0])
train_labels_cat = to_categorical(train_labels, num_classes=2)
train_data = to_categorical(train_data.values.reshape(train_data.shape[0], SEQ_SIZE, 1), num_classes=4)
test_labels = test_data.pop(test_data.columns[0])
test_labels_cat = to_categorical(test_labels, num_classes=2)
test_data = to_categorical(test_data.values.reshape(test_data.shape[0], SEQ_SIZE, 1), num_classes=4)

# %%
def get_identity_block(inpt, num_filts, filt_sz = 3, activation = tf.nn.relu6, strides = 1, pad = 'same', ):
    conv_layer = tf.keras.layers.Conv1D(
        filters = num_filts, kernel_size = filt_sz, 
        strides = strides, kernel_regularizer='L1L2', 
        padding = pad, data_format='channels_last', use_bias=False)(inpt)
    batch_norm = tf.keras.layers.BatchNormalization(scale = False,)(conv_layer)
    act_layer = tf.keras.layers.Activation(activation)(batch_norm)
    conv_layer = tf.keras.layers.Conv1D(
        filters = num_filts, kernel_size = filt_sz, 
        strides = strides, kernel_regularizer='L1L2', 
        padding = pad, data_format='channels_last', use_bias=False)(act_layer)
    batch_norm = tf.keras.layers.BatchNormalization(scale = False,)(conv_layer)
    act_layer = tf.keras.layers.Activation(activation)(batch_norm)
    add_layer = tf.keras.layers.add([inpt, act_layer])
    return tf.keras.layers.Activation(activation)(add_layer)

def get_resblock(inpt, num_filts, filt_sz = 3, activation = tf.nn.relu6, strides = 1, pad = 'same', ):
    conv_layer = tf.keras.layers.Conv1D(
        filters = num_filts, kernel_size = filt_sz, 
        strides = strides, kernel_regularizer='L1L2', 
        padding = pad, data_format='channels_last', use_bias=False)(inpt)
    batch_norm = tf.keras.layers.BatchNormalization(scale = False,)(conv_layer)
    act_layer = tf.keras.layers.Activation(activation)(batch_norm)
    conv_layer = tf.keras.layers.Conv1D(
        filters = num_filts, kernel_size = filt_sz, 
        strides = strides, kernel_regularizer='L1L2', 
        padding = pad, data_format='channels_last', use_bias=False)(act_layer)
    batch_norm = tf.keras.layers.BatchNormalization(scale = False,)(conv_layer)
    act_layer = tf.keras.layers.Activation(activation)(batch_norm)
    conv_1_1 = tf.keras.layers.Conv1D(
        filters = num_filts, kernel_size = 1, 
        strides = 1, kernel_regularizer='L1L2', 
        padding = pad, data_format='channels_last', use_bias=False)(inpt)
    add_layer = tf.keras.layers.add([conv_1_1, act_layer])
    return tf.keras.layers.Activation(activation)(add_layer)

def get_compiled_model():

    relu_act = tf.keras.layers.Activation(tf.nn.relu6)

    input_layer = tf.keras.layers.Input(batch_shape=(None, SEQ_SIZE, 4), name='input')
    pad_layer = tf.keras.layers.ZeroPadding1D(3)(input_layer)
    x = tf.keras.layers.Conv1D(64, kernel_size=7, strides=2, padding='same')(pad_layer)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPool1D(pool_size=3, strides=2, padding='same')(x)

    
    block_layers = [3, 4, 6, 3]
    filter_size = 64

    for i in range(4):
        if i == 0:
            for j in range(block_layers[i]):
                x = get_identity_block(x, filter_size)
        else:
            filter_size = filter_size*2
            x = get_resblock(x, filter_size)
            for j in range(block_layers[i] - 1):
                x = get_identity_block(x, filter_size)

    x = tf.keras.layers.AveragePooling1D(2, padding = 'same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(512, activation = 'relu')(x)
    x = tf.keras.layers.Dense(2, activation = 'softmax')(x)

    model = tf.keras.models.Model(inputs = input_layer, outputs = x, name = "ResNet34")
    model.compile(optimizer=tf.optimizers.Adam(0.001), loss = tf.losses.categorical_crossentropy, metrics=['accuracy'])
    model.summary()
    return model

model = get_compiled_model()
# Out:
# Model: "ResNet34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 151, 4)]     0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 157, 4)      0           ['input[0][0]']
#
#  conv1d (Conv1D)                (None, 79, 64)       1856        ['zero_padding1d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 79, 64)      256         ['conv1d[0][0]']
#  alization)
#
#  activation_1 (Activation)      (None, 79, 64)       0           ['batch_normalization[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 40, 64)       0           ['activation_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 40, 64)       12288       ['max_pooling1d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 40, 64)      192         ['conv1d_1[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 40, 64)       0           ['batch_normalization_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 40, 64)       12288       ['activation_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 40, 64)      192         ['conv1d_2[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 40, 64)       0           ['batch_normalization_2[0][0]']
#
#  add (Add)                      (None, 40, 64)       0           ['max_pooling1d[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 40, 64)       0           ['add[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 40, 64)       12288       ['activation_4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 40, 64)      192         ['conv1d_3[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 40, 64)       0           ['batch_normalization_3[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 40, 64)       12288       ['activation_5[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 40, 64)      192         ['conv1d_4[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 40, 64)       0           ['batch_normalization_4[0][0]']
#
#  add_1 (Add)                    (None, 40, 64)       0           ['activation_4[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 40, 64)       0           ['add_1[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 40, 64)       12288       ['activation_7[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 40, 64)      192         ['conv1d_5[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 40, 64)       0           ['batch_normalization_5[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 40, 64)       12288       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 40, 64)      192         ['conv1d_6[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 40, 64)       0           ['batch_normalization_6[0][0]']
#
#  add_2 (Add)                    (None, 40, 64)       0           ['activation_7[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_10 (Activation)     (None, 40, 64)       0           ['add_2[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 40, 128)      24576       ['activation_10[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 40, 128)     384         ['conv1d_7[0][0]']
#  rmalization)
#
#  activation_11 (Activation)     (None, 40, 128)      0           ['batch_normalization_7[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 40, 128)      49152       ['activation_11[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 40, 128)     384         ['conv1d_8[0][0]']
#  rmalization)
#
#  conv1d_9 (Conv1D)              (None, 40, 128)      8192        ['activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 40, 128)      0           ['batch_normalization_8[0][0]']
#
#  add_3 (Add)                    (None, 40, 128)      0           ['conv1d_9[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_13 (Activation)     (None, 40, 128)      0           ['add_3[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 40, 128)      49152       ['activation_13[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 40, 128)     384         ['conv1d_10[0][0]']
#  rmalization)
#
#  activation_14 (Activation)     (None, 40, 128)      0           ['batch_normalization_9[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 40, 128)      49152       ['activation_14[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 40, 128)     384         ['conv1d_11[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 40, 128)      0           ['batch_normalization_10[0][0]']
#
#  add_4 (Add)                    (None, 40, 128)      0           ['activation_13[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_16 (Activation)     (None, 40, 128)      0           ['add_4[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 40, 128)      49152       ['activation_16[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 40, 128)     384         ['conv1d_12[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 40, 128)      0           ['batch_normalization_11[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 40, 128)      49152       ['activation_17[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 40, 128)     384         ['conv1d_13[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 40, 128)      0           ['batch_normalization_12[0][0]']
#
#  add_5 (Add)                    (None, 40, 128)      0           ['activation_16[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_19 (Activation)     (None, 40, 128)      0           ['add_5[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 40, 128)      49152       ['activation_19[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 40, 128)     384         ['conv1d_14[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 40, 128)      0           ['batch_normalization_13[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 40, 128)      49152       ['activation_20[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 40, 128)     384         ['conv1d_15[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 40, 128)      0           ['batch_normalization_14[0][0]']
#
#  add_6 (Add)                    (None, 40, 128)      0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]']
#
#  activation_22 (Activation)     (None, 40, 128)      0           ['add_6[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 40, 256)      98304       ['activation_22[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 40, 256)     768         ['conv1d_16[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 40, 256)      0           ['batch_normalization_15[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 40, 256)      196608      ['activation_23[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 40, 256)     768         ['conv1d_17[0][0]']
#  ormalization)
#
#  conv1d_18 (Conv1D)             (None, 40, 256)      32768       ['activation_22[0][0]']
#
#  activation_24 (Activation)     (None, 40, 256)      0           ['batch_normalization_16[0][0]']
#
#  add_7 (Add)                    (None, 40, 256)      0           ['conv1d_18[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_25 (Activation)     (None, 40, 256)      0           ['add_7[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 40, 256)      196608      ['activation_25[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 40, 256)     768         ['conv1d_19[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 40, 256)      0           ['batch_normalization_17[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 40, 256)      196608      ['activation_26[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 40, 256)     768         ['conv1d_20[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 40, 256)      0           ['batch_normalization_18[0][0]']
#
#  add_8 (Add)                    (None, 40, 256)      0           ['activation_25[0][0]',
#                                                                   'activation_27[0][0]']
#
#  activation_28 (Activation)     (None, 40, 256)      0           ['add_8[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 40, 256)      196608      ['activation_28[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 40, 256)     768         ['conv1d_21[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 40, 256)      0           ['batch_normalization_19[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 40, 256)      196608      ['activation_29[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 40, 256)     768         ['conv1d_22[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 40, 256)      0           ['batch_normalization_20[0][0]']
#
#  add_9 (Add)                    (None, 40, 256)      0           ['activation_28[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_31 (Activation)     (None, 40, 256)      0           ['add_9[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 40, 256)      196608      ['activation_31[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 40, 256)     768         ['conv1d_23[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 40, 256)      0           ['batch_normalization_21[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 40, 256)      196608      ['activation_32[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 40, 256)     768         ['conv1d_24[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 40, 256)      0           ['batch_normalization_22[0][0]']
#
#  add_10 (Add)                   (None, 40, 256)      0           ['activation_31[0][0]',
#                                                                   'activation_33[0][0]']
#
#  activation_34 (Activation)     (None, 40, 256)      0           ['add_10[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 40, 256)      196608      ['activation_34[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 40, 256)     768         ['conv1d_25[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 40, 256)      0           ['batch_normalization_23[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 40, 256)      196608      ['activation_35[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 40, 256)     768         ['conv1d_26[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 40, 256)      0           ['batch_normalization_24[0][0]']
#
#  add_11 (Add)                   (None, 40, 256)      0           ['activation_34[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_37 (Activation)     (None, 40, 256)      0           ['add_11[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 40, 256)      196608      ['activation_37[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 40, 256)     768         ['conv1d_27[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 40, 256)      0           ['batch_normalization_25[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 40, 256)      196608      ['activation_38[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 40, 256)     768         ['conv1d_28[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 40, 256)      0           ['batch_normalization_26[0][0]']
#
#  add_12 (Add)                   (None, 40, 256)      0           ['activation_37[0][0]',
#                                                                   'activation_39[0][0]']
#
#  activation_40 (Activation)     (None, 40, 256)      0           ['add_12[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 40, 512)      393216      ['activation_40[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 40, 512)     1536        ['conv1d_29[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 40, 512)      0           ['batch_normalization_27[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 40, 512)      786432      ['activation_41[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 40, 512)     1536        ['conv1d_30[0][0]']
#  ormalization)
#
#  conv1d_31 (Conv1D)             (None, 40, 512)      131072      ['activation_40[0][0]']
#
#  activation_42 (Activation)     (None, 40, 512)      0           ['batch_normalization_28[0][0]']
#
#  add_13 (Add)                   (None, 40, 512)      0           ['conv1d_31[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_43 (Activation)     (None, 40, 512)      0           ['add_13[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 40, 512)      786432      ['activation_43[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 40, 512)     1536        ['conv1d_32[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 40, 512)      0           ['batch_normalization_29[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 40, 512)      786432      ['activation_44[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 40, 512)     1536        ['conv1d_33[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 40, 512)      0           ['batch_normalization_30[0][0]']
#
#  add_14 (Add)                   (None, 40, 512)      0           ['activation_43[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_46 (Activation)     (None, 40, 512)      0           ['add_14[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 40, 512)      786432      ['activation_46[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 40, 512)     1536        ['conv1d_34[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 40, 512)      0           ['batch_normalization_31[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 40, 512)      786432      ['activation_47[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 40, 512)     1536        ['conv1d_35[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 40, 512)      0           ['batch_normalization_32[0][0]']
#
#  add_15 (Add)                   (None, 40, 512)      0           ['activation_46[0][0]',
#                                                                   'activation_48[0][0]']
#
#  activation_49 (Activation)     (None, 40, 512)      0           ['add_15[0][0]']
#
#  average_pooling1d (AveragePool  (None, 20, 512)     0           ['activation_49[0][0]']
#  ing1D)
#
#  flatten (Flatten)              (None, 10240)        0           ['average_pooling1d[0][0]']
#
#  dense (Dense)                  (None, 512)          5243392     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 2)            1026        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 12,469,954
# Trainable params: 12,454,722
# Non-trainable params: 15,232
# __________________________________________________________________________________________________

# %%
early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min", patience = 4, verbose=1)
redonplat = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_accuracy", mode="max", patience=3, verbose=2)
callbacks_list = [early, redonplat, tf.keras.callbacks.TensorBoard('logs')]

# %%
hist = model.fit(train_data, train_labels_cat, epochs=100, validation_split=0.20, batch_size=32, callbacks=callbacks_list, shuffle=True)
# Out:
# Epoch 1/100
# 285/285 [==============================] - 44s 93ms/step - loss: 1.5627 - accuracy: 0.7783 - val_loss: 0.4926 - val_accuracy: 0.7604 - lr: 0.0010
# Epoch 2/100
# 285/285 [==============================] - 23s 80ms/step - loss: 0.3570 - accuracy: 0.8523 - val_loss: 0.5227 - val_accuracy: 0.7973 - lr: 0.0010
# Epoch 3/100
# 285/285 [==============================] - 22s 78ms/step - loss: 0.2556 - accuracy: 0.8972 - val_loss: 0.6444 - val_accuracy: 0.7288 - lr: 0.0010
# Epoch 4/100
# 285/285 [==============================] - 19s 68ms/step - loss: 0.2222 - accuracy: 0.9099 - val_loss: 0.3629 - val_accuracy: 0.8605 - lr: 0.0010
# Epoch 5/100
# 285/285 [==============================] - 19s 68ms/step - loss: 0.1786 - accuracy: 0.9315 - val_loss: 0.4211 - val_accuracy: 0.8451 - lr: 0.0010
# Epoch 6/100
# 285/285 [==============================] - 20s 69ms/step - loss: 0.1477 - accuracy: 0.9432 - val_loss: 0.4830 - val_accuracy: 0.8394 - lr: 0.0010
# Epoch 7/100
# 285/285 [==============================] - 19s 68ms/step - loss: 0.1414 - accuracy: 0.9439 - val_loss: 0.3411 - val_accuracy: 0.8741 - lr: 0.0010
# Epoch 8/100
# 285/285 [==============================] - 20s 69ms/step - loss: 0.1245 - accuracy: 0.9514 - val_loss: 0.3477 - val_accuracy: 0.8728 - lr: 0.0010
# Epoch 9/100
# 285/285 [==============================] - 20s 70ms/step - loss: 0.1106 - accuracy: 0.9592 - val_loss: 0.3612 - val_accuracy: 0.8767 - lr: 0.0010
# Epoch 10/100
# 285/285 [==============================] - 20s 69ms/step - loss: 0.0936 - accuracy: 0.9652 - val_loss: 0.3826 - val_accuracy: 0.8798 - lr: 0.0010
# Epoch 11/100
# 285/285 [==============================] - 19s 68ms/step - loss: 0.0919 - accuracy: 0.9629 - val_loss: 0.3860 - val_accuracy: 0.8754 - lr: 0.0010
# Epoch 11: early stopping

# %%
pred_test = np.argmax(model.predict(test_data), axis = 1)
accuracy = accuracy_score(test_labels, pred_test)
print("Testing Accuracy: ", accuracy)
# Out:
# Testing Accuracy:  0.8837780898876404

# %%
cf_m = tf.math.confusion_matrix(test_labels, pred_test, num_classes=2)
print(cf_m)
# Out:
# tf.Tensor(
# [[1212  196]
#  [ 135 1305]], shape=(2, 2), dtype=int32)

# %%
recall = precision_recall_fscore_support(test_labels, pred_test, average="binary")
print('Precision: {0:0.2f}'.format(recall[0]))
print('Recall: {0:1.2f}'.format(recall[1]))
print('F1-Score: {0:2.2f}'.format(recall[2]))
# Out:
# Precision: 0.87
# Recall: 0.91
# F1-Score: 0.89

# %%
pred_test = np.argmax(model.predict(test_data), axis = 1)
pred_test = to_categorical(pred_test)
ns_auc = roc_auc_score(test_labels_cat[:, 0], pred_test[:, 0])
lr_auc = roc_auc_score(test_labels_cat[:, 1], pred_test[:, 1])
print('Non-Promoter: ROC AUC=%.3f' % (ns_auc))
print('Promoter: ROC AUC=%.3f' % (lr_auc))
ns_fpr, ns_tpr, _ = roc_curve(test_labels_cat[:, 0], pred_test[:, 0])
lr_fpr, lr_tpr, _ = roc_curve(test_labels_cat[:, 1], pred_test[:, 1])
# Out:
# Non-Promoter: ROC AUC=0.884
# Promoter: ROC AUC=0.884

# %%
fig = plt.figure(figsize=(25, 20))
plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Non-Promoter', linewidth=4)
plt.plot(lr_fpr, lr_tpr, marker='.', label='Promoter', linewidth=4)
plt.xlabel('False Positive Rate', fontsize=fontsize)
plt.ylabel('True Positive Rate', fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.legend(fontsize=fontsize)
plt.savefig("roc_resnet.png")

# %%
summ = hist.history

epochs = [i for i in range(1, len(summ['loss'])+1)]

fig = plt.figure(figsize=(25, 20))
plt.plot(epochs, summ['loss'], color='blue', label="training_loss", linewidth=4)
plt.plot(epochs, summ['val_loss'], color='red', label="validation_loss", linewidth=4)
plt.legend(loc='best', fontsize=fontsize)
plt.title('Loss vs Epoch', fontsize=fontsize)
plt.ylabel('Loss', fontsize=fontsize)
plt.xlabel('Epoch', fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
# plt.show()
plt.savefig("loss_resnet.png")

fig = plt.figure(figsize=(25, 20))
plt.plot(epochs, summ['accuracy'], color='blue', label="training_accuracy", linewidth=4)
plt.plot(epochs, summ['val_accuracy'], color='red',label="validation_accuracy", linewidth=4)
plt.legend(loc='best', fontsize=fontsize)
plt.title('Accuracy vs Epoch', fontsize=fontsize)
plt.ylabel('Accuracy', fontsize=fontsize)
plt.xlabel('Epoch', fontsize=fontsize)
# plt.show()
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.savefig("accuracy_resnet.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [12], in <module>
#      15 plt.savefig("loss_resnet.png")
#      17 fig = plt.figure(figsize=(25, 20))
# ---> 18 plt.plot(epochs, summ['categorical_accuracy'], color='blue', label="training_accuracy", linewidth=4)
#      19 plt.plot(epochs, summ['val_categorical_accuracy'], color='red',label="validation_accuracy", linewidth=4)
#      20 plt.legend(loc='best', fontsize=fontsize)
#
# KeyError: 'categorical_accuracy'
