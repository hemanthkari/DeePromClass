# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import pandas as pd
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import average_precision_score, precision_recall_fscore_support, accuracy_score, roc_curve, roc_auc_score
import numpy as np
import keras
import matplotlib.pyplot as plt

# %%
SEQ_SIZE = 151

fontsize = 24
train_file_path = "train_data.csv"

df = pd.read_csv(train_file_path)
df = df.sample(frac = 1)

split_data = int(df.shape[0]*0.8)
train_data = df[:split_data]
test_data = df[split_data:]
train_labels = train_data.pop(train_data.columns[0])
train_labels_cat = to_categorical(train_labels, num_classes=2)
train_data = to_categorical(train_data.values.reshape(train_data.shape[0], SEQ_SIZE, 1), num_classes=4)
test_labels = test_data.pop(test_data.columns[0])
test_labels_cat = to_categorical(test_labels, num_classes=2)
test_data = to_categorical(test_data.values.reshape(test_data.shape[0], SEQ_SIZE, 1), num_classes=4)

# %%
def get_conv1d_layer(inpt, num_filts, filt_sz, activation = tf.nn.relu6, strides = 1, pad = 'same', ):
    conv_layer = tf.keras.layers.Conv1D(
        filters = num_filts, kernel_size = filt_sz, 
        strides = strides, kernel_regularizer='L1L2', 
        padding = pad, data_format='channels_last', use_bias=False)(inpt)
    batch_norm = tf.keras.layers.BatchNormalization(scale = False,)(conv_layer)
    return tf.keras.layers.Activation(activation)(batch_norm)

def get_compiled_model():
    
    relu_act = tf.keras.layers.Activation(tf.nn.relu6)

    def get_res_incep_block(inpt, pad = 'same', data_format = 'channels_last', use_bias = False, scale = 0.6):
        rel_act = relu_act(inpt)
        conv_0_1 = get_conv1d_layer(rel_act, 32, 1)
        conv_1_1 = get_conv1d_layer(rel_act, 32, 1)
        conv_2_1 = get_conv1d_layer(rel_act, 32, 1)
        conv_1_2 = get_conv1d_layer(conv_1_1, 32, 3)
        conv_2_2 = get_conv1d_layer(conv_2_1, 48, 3)
        conv_2_3 = get_conv1d_layer(conv_2_2, 64, 3)
        concat_conv = tf.keras.layers.Concatenate()([conv_0_1, conv_2_3, conv_1_2])
        filter_conv = get_conv1d_layer(concat_conv, 384, 1, activation = "linear")
#         final_add_layer = tf.keras.layers.Add()([rel_act, filter_conv])
        final_add_layer = tf.keras.layers.Lambda(lambda inputs, scale: inputs[0] + inputs[1] * scale,
                      output_shape = tf.keras.backend.int_shape(rel_act)[1:],
                      arguments={'scale': scale})([rel_act, filter_conv])
        batch_norm = tf.keras.layers.BatchNormalization()(final_add_layer)
        return relu_act(batch_norm)

    input_layer = tf.keras.layers.Input(batch_shape=(None, SEQ_SIZE, 4), name='input')
    conv1_layer = get_conv1d_layer(input_layer, 32, 1)
    conv2_layer = get_conv1d_layer(input_layer, 384, 1)

    incp_layer = get_res_incep_block(conv2_layer)
    for _ in range(0, 9):
        incp_layer = get_res_incep_block(incp_layer)

    out_pool = tf.keras.layers.GlobalAveragePooling1D()(incp_layer)
    out_dropout = tf.keras.layers.Dropout(0.6)(out_pool)
    hid_dense = tf.keras.layers.Dense(1024, activation = 'linear')(out_dropout)
    out_dense = tf.keras.layers.Dense(2, activation = 'softmax')(hid_dense)

    model = tf.keras.models.Model(inputs = input_layer, outputs = out_dense)
    model.compile(optimizer=tf.optimizers.Adam(0.001), loss = tf.losses.categorical_crossentropy, metrics=['accuracy'])
    model.summary()

    return model

model = get_compiled_model()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 151, 4)]     0           []
#
#  conv1d_1 (Conv1D)              (None, 151, 384)     1536        ['input[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 151, 384)    1152        ['conv1d_1[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 151, 384)     0           ['batch_normalization_1[0][0]']
#
#  activation (Activation)        (None, 151, 384)     0           ['activation_2[0][0]',
#                                                                   'batch_normalization_9[0][0]',
#                                                                   'activation[1][0]',
#                                                                   'batch_normalization_17[0][0]',
#                                                                   'activation[3][0]',
#                                                                   'batch_normalization_25[0][0]',
#                                                                   'activation[5][0]',
#                                                                   'batch_normalization_33[0][0]',
#                                                                   'activation[7][0]',
#                                                                   'batch_normalization_41[0][0]',
#                                                                   'activation[9][0]',
#                                                                   'batch_normalization_49[0][0]',
#                                                                   'activation[11][0]',
#                                                                   'batch_normalization_57[0][0]',
#                                                                   'activation[13][0]',
#                                                                   'batch_normalization_65[0][0]',
#                                                                   'activation[15][0]',
#                                                                   'batch_normalization_73[0][0]',
#                                                                   'activation[17][0]',
#                                                                   'batch_normalization_81[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 151, 32)      12288       ['activation[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 151, 32)     96          ['conv1d_4[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 151, 32)      0           ['batch_normalization_4[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 151, 48)      4608        ['activation_5[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 151, 32)      12288       ['activation[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 151, 48)     144         ['conv1d_6[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 151, 32)     96          ['conv1d_3[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 151, 48)      0           ['batch_normalization_6[0][0]']
#
#  activation_4 (Activation)      (None, 151, 32)      0           ['batch_normalization_3[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 151, 32)      12288       ['activation[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 151, 64)      9216        ['activation_7[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 151, 32)      3072        ['activation_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 151, 32)     96          ['conv1d_2[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 151, 64)     192         ['conv1d_7[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 151, 32)     96          ['conv1d_5[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 151, 32)      0           ['batch_normalization_2[0][0]']
#
#  activation_8 (Activation)      (None, 151, 64)      0           ['batch_normalization_7[0][0]']
#
#  activation_6 (Activation)      (None, 151, 32)      0           ['batch_normalization_5[0][0]']
#
#  concatenate (Concatenate)      (None, 151, 128)     0           ['activation_3[0][0]',
#                                                                   'activation_8[0][0]',
#                                                                   'activation_6[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 151, 384)     49152       ['concatenate[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 151, 384)    1152        ['conv1d_8[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 151, 384)     0           ['batch_normalization_8[0][0]']
#
#  lambda (Lambda)                (None, 151, 384)     0           ['activation[0][0]',
#                                                                   'activation_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 151, 384)    1536        ['lambda[0][0]']
#  rmalization)
#
#  conv1d_11 (Conv1D)             (None, 151, 32)      12288       ['activation[2][0]']
#
#  batch_normalization_12 (BatchN  (None, 151, 32)     96          ['conv1d_11[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 151, 32)      0           ['batch_normalization_12[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 151, 48)      4608        ['activation_12[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 151, 32)      12288       ['activation[2][0]']
#
#  batch_normalization_14 (BatchN  (None, 151, 48)     144         ['conv1d_13[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 151, 32)     96          ['conv1d_10[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 151, 48)      0           ['batch_normalization_14[0][0]']
#
#  activation_11 (Activation)     (None, 151, 32)      0           ['batch_normalization_11[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 151, 32)      12288       ['activation[2][0]']
#
#  conv1d_14 (Conv1D)             (None, 151, 64)      9216        ['activation_14[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 151, 32)      3072        ['activation_11[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 151, 32)     96          ['conv1d_9[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 151, 64)     192         ['conv1d_14[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 151, 32)     96          ['conv1d_12[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 151, 32)      0           ['batch_normalization_10[0][0]']
#
#  activation_15 (Activation)     (None, 151, 64)      0           ['batch_normalization_15[0][0]']
#
#  activation_13 (Activation)     (None, 151, 32)      0           ['batch_normalization_13[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 151, 128)     0           ['activation_10[0][0]',
#                                                                   'activation_15[0][0]',
#                                                                   'activation_13[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 151, 384)     49152       ['concatenate_1[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 151, 384)    1152        ['conv1d_15[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 151, 384)     0           ['batch_normalization_16[0][0]']
#
#  lambda_1 (Lambda)              (None, 151, 384)     0           ['activation[2][0]',
#                                                                   'activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 151, 384)    1536        ['lambda_1[0][0]']
#  ormalization)
#
#  conv1d_18 (Conv1D)             (None, 151, 32)      12288       ['activation[4][0]']
#
#  batch_normalization_20 (BatchN  (None, 151, 32)     96          ['conv1d_18[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 151, 32)      0           ['batch_normalization_20[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 151, 48)      4608        ['activation_19[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 151, 32)      12288       ['activation[4][0]']
#
#  batch_normalization_22 (BatchN  (None, 151, 48)     144         ['conv1d_20[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 151, 32)     96          ['conv1d_17[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 151, 48)      0           ['batch_normalization_22[0][0]']
#
#  activation_18 (Activation)     (None, 151, 32)      0           ['batch_normalization_19[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 151, 32)      12288       ['activation[4][0]']
#
#  conv1d_21 (Conv1D)             (None, 151, 64)      9216        ['activation_21[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 151, 32)      3072        ['activation_18[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 151, 32)     96          ['conv1d_16[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 151, 64)     192         ['conv1d_21[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 151, 32)     96          ['conv1d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 151, 32)      0           ['batch_normalization_18[0][0]']
#
#  activation_22 (Activation)     (None, 151, 64)      0           ['batch_normalization_23[0][0]']
#
#  activation_20 (Activation)     (None, 151, 32)      0           ['batch_normalization_21[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 151, 128)     0           ['activation_17[0][0]',
#                                                                   'activation_22[0][0]',
#                                                                   'activation_20[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 151, 384)     49152       ['concatenate_2[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 151, 384)    1152        ['conv1d_22[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 151, 384)     0           ['batch_normalization_24[0][0]']
#
#  lambda_2 (Lambda)              (None, 151, 384)     0           ['activation[4][0]',
#                                                                   'activation_23[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 151, 384)    1536        ['lambda_2[0][0]']
#  ormalization)
#
#  conv1d_25 (Conv1D)             (None, 151, 32)      12288       ['activation[6][0]']
#
#  batch_normalization_28 (BatchN  (None, 151, 32)     96          ['conv1d_25[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 151, 32)      0           ['batch_normalization_28[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 151, 48)      4608        ['activation_26[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 151, 32)      12288       ['activation[6][0]']
#
#  batch_normalization_30 (BatchN  (None, 151, 48)     144         ['conv1d_27[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 151, 32)     96          ['conv1d_24[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 151, 48)      0           ['batch_normalization_30[0][0]']
#
#  activation_25 (Activation)     (None, 151, 32)      0           ['batch_normalization_27[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 151, 32)      12288       ['activation[6][0]']
#
#  conv1d_28 (Conv1D)             (None, 151, 64)      9216        ['activation_28[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 151, 32)      3072        ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 151, 32)     96          ['conv1d_23[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 151, 64)     192         ['conv1d_28[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 151, 32)     96          ['conv1d_26[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 151, 32)      0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 151, 64)      0           ['batch_normalization_31[0][0]']
#
#  activation_27 (Activation)     (None, 151, 32)      0           ['batch_normalization_29[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 151, 128)     0           ['activation_24[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'activation_27[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 151, 384)     49152       ['concatenate_3[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 151, 384)    1152        ['conv1d_29[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 151, 384)     0           ['batch_normalization_32[0][0]']
#
#  lambda_3 (Lambda)              (None, 151, 384)     0           ['activation[6][0]',
#                                                                   'activation_30[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 151, 384)    1536        ['lambda_3[0][0]']
#  ormalization)
#
#  conv1d_32 (Conv1D)             (None, 151, 32)      12288       ['activation[8][0]']
#
#  batch_normalization_36 (BatchN  (None, 151, 32)     96          ['conv1d_32[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 151, 32)      0           ['batch_normalization_36[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 151, 48)      4608        ['activation_33[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 151, 32)      12288       ['activation[8][0]']
#
#  batch_normalization_38 (BatchN  (None, 151, 48)     144         ['conv1d_34[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 151, 32)     96          ['conv1d_31[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 151, 48)      0           ['batch_normalization_38[0][0]']
#
#  activation_32 (Activation)     (None, 151, 32)      0           ['batch_normalization_35[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 151, 32)      12288       ['activation[8][0]']
#
#  conv1d_35 (Conv1D)             (None, 151, 64)      9216        ['activation_35[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 151, 32)      3072        ['activation_32[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 151, 32)     96          ['conv1d_30[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 151, 64)     192         ['conv1d_35[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 151, 32)     96          ['conv1d_33[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 151, 32)      0           ['batch_normalization_34[0][0]']
#
#  activation_36 (Activation)     (None, 151, 64)      0           ['batch_normalization_39[0][0]']
#
#  activation_34 (Activation)     (None, 151, 32)      0           ['batch_normalization_37[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 151, 128)     0           ['activation_31[0][0]',
#                                                                   'activation_36[0][0]',
#                                                                   'activation_34[0][0]']
#
#  conv1d_36 (Conv1D)             (None, 151, 384)     49152       ['concatenate_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 151, 384)    1152        ['conv1d_36[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 151, 384)     0           ['batch_normalization_40[0][0]']
#
#  lambda_4 (Lambda)              (None, 151, 384)     0           ['activation[8][0]',
#                                                                   'activation_37[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 151, 384)    1536        ['lambda_4[0][0]']
#  ormalization)
#
#  conv1d_39 (Conv1D)             (None, 151, 32)      12288       ['activation[10][0]']
#
#  batch_normalization_44 (BatchN  (None, 151, 32)     96          ['conv1d_39[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 151, 32)      0           ['batch_normalization_44[0][0]']
#
#  conv1d_41 (Conv1D)             (None, 151, 48)      4608        ['activation_40[0][0]']
#
#  conv1d_38 (Conv1D)             (None, 151, 32)      12288       ['activation[10][0]']
#
#  batch_normalization_46 (BatchN  (None, 151, 48)     144         ['conv1d_41[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 151, 32)     96          ['conv1d_38[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 151, 48)      0           ['batch_normalization_46[0][0]']
#
#  activation_39 (Activation)     (None, 151, 32)      0           ['batch_normalization_43[0][0]']
#
#  conv1d_37 (Conv1D)             (None, 151, 32)      12288       ['activation[10][0]']
#
#  conv1d_42 (Conv1D)             (None, 151, 64)      9216        ['activation_42[0][0]']
#
#  conv1d_40 (Conv1D)             (None, 151, 32)      3072        ['activation_39[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 151, 32)     96          ['conv1d_37[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 151, 64)     192         ['conv1d_42[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 151, 32)     96          ['conv1d_40[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 151, 32)      0           ['batch_normalization_42[0][0]']
#
#  activation_43 (Activation)     (None, 151, 64)      0           ['batch_normalization_47[0][0]']
#
#  activation_41 (Activation)     (None, 151, 32)      0           ['batch_normalization_45[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 151, 128)     0           ['activation_38[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_41[0][0]']
#
#  conv1d_43 (Conv1D)             (None, 151, 384)     49152       ['concatenate_5[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 151, 384)    1152        ['conv1d_43[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 151, 384)     0           ['batch_normalization_48[0][0]']
#
#  lambda_5 (Lambda)              (None, 151, 384)     0           ['activation[10][0]',
#                                                                   'activation_44[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 151, 384)    1536        ['lambda_5[0][0]']
#  ormalization)
#
#  conv1d_46 (Conv1D)             (None, 151, 32)      12288       ['activation[12][0]']
#
#  batch_normalization_52 (BatchN  (None, 151, 32)     96          ['conv1d_46[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 151, 32)      0           ['batch_normalization_52[0][0]']
#
#  conv1d_48 (Conv1D)             (None, 151, 48)      4608        ['activation_47[0][0]']
#
#  conv1d_45 (Conv1D)             (None, 151, 32)      12288       ['activation[12][0]']
#
#  batch_normalization_54 (BatchN  (None, 151, 48)     144         ['conv1d_48[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 151, 32)     96          ['conv1d_45[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 151, 48)      0           ['batch_normalization_54[0][0]']
#
#  activation_46 (Activation)     (None, 151, 32)      0           ['batch_normalization_51[0][0]']
#
#  conv1d_44 (Conv1D)             (None, 151, 32)      12288       ['activation[12][0]']
#
#  conv1d_49 (Conv1D)             (None, 151, 64)      9216        ['activation_49[0][0]']
#
#  conv1d_47 (Conv1D)             (None, 151, 32)      3072        ['activation_46[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 151, 32)     96          ['conv1d_44[0][0]']
#  ormalization)
#
#  batch_normalization_55 (BatchN  (None, 151, 64)     192         ['conv1d_49[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 151, 32)     96          ['conv1d_47[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 151, 32)      0           ['batch_normalization_50[0][0]']
#
#  activation_50 (Activation)     (None, 151, 64)      0           ['batch_normalization_55[0][0]']
#
#  activation_48 (Activation)     (None, 151, 32)      0           ['batch_normalization_53[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 151, 128)     0           ['activation_45[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_48[0][0]']
#
#  conv1d_50 (Conv1D)             (None, 151, 384)     49152       ['concatenate_6[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 151, 384)    1152        ['conv1d_50[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 151, 384)     0           ['batch_normalization_56[0][0]']
#
#  lambda_6 (Lambda)              (None, 151, 384)     0           ['activation[12][0]',
#                                                                   'activation_51[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 151, 384)    1536        ['lambda_6[0][0]']
#  ormalization)
#
#  conv1d_53 (Conv1D)             (None, 151, 32)      12288       ['activation[14][0]']
#
#  batch_normalization_60 (BatchN  (None, 151, 32)     96          ['conv1d_53[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 151, 32)      0           ['batch_normalization_60[0][0]']
#
#  conv1d_55 (Conv1D)             (None, 151, 48)      4608        ['activation_54[0][0]']
#
#  conv1d_52 (Conv1D)             (None, 151, 32)      12288       ['activation[14][0]']
#
#  batch_normalization_62 (BatchN  (None, 151, 48)     144         ['conv1d_55[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 151, 32)     96          ['conv1d_52[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 151, 48)      0           ['batch_normalization_62[0][0]']
#
#  activation_53 (Activation)     (None, 151, 32)      0           ['batch_normalization_59[0][0]']
#
#  conv1d_51 (Conv1D)             (None, 151, 32)      12288       ['activation[14][0]']
#
#  conv1d_56 (Conv1D)             (None, 151, 64)      9216        ['activation_56[0][0]']
#
#  conv1d_54 (Conv1D)             (None, 151, 32)      3072        ['activation_53[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 151, 32)     96          ['conv1d_51[0][0]']
#  ormalization)
#
#  batch_normalization_63 (BatchN  (None, 151, 64)     192         ['conv1d_56[0][0]']
#  ormalization)
#
#  batch_normalization_61 (BatchN  (None, 151, 32)     96          ['conv1d_54[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 151, 32)      0           ['batch_normalization_58[0][0]']
#
#  activation_57 (Activation)     (None, 151, 64)      0           ['batch_normalization_63[0][0]']
#
#  activation_55 (Activation)     (None, 151, 32)      0           ['batch_normalization_61[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 151, 128)     0           ['activation_52[0][0]',
#                                                                   'activation_57[0][0]',
#                                                                   'activation_55[0][0]']
#
#  conv1d_57 (Conv1D)             (None, 151, 384)     49152       ['concatenate_7[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 151, 384)    1152        ['conv1d_57[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 151, 384)     0           ['batch_normalization_64[0][0]']
#
#  lambda_7 (Lambda)              (None, 151, 384)     0           ['activation[14][0]',
#                                                                   'activation_58[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 151, 384)    1536        ['lambda_7[0][0]']
#  ormalization)
#
#  conv1d_60 (Conv1D)             (None, 151, 32)      12288       ['activation[16][0]']
#
#  batch_normalization_68 (BatchN  (None, 151, 32)     96          ['conv1d_60[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 151, 32)      0           ['batch_normalization_68[0][0]']
#
#  conv1d_62 (Conv1D)             (None, 151, 48)      4608        ['activation_61[0][0]']
#
#  conv1d_59 (Conv1D)             (None, 151, 32)      12288       ['activation[16][0]']
#
#  batch_normalization_70 (BatchN  (None, 151, 48)     144         ['conv1d_62[0][0]']
#  ormalization)
#
#  batch_normalization_67 (BatchN  (None, 151, 32)     96          ['conv1d_59[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 151, 48)      0           ['batch_normalization_70[0][0]']
#
#  activation_60 (Activation)     (None, 151, 32)      0           ['batch_normalization_67[0][0]']
#
#  conv1d_58 (Conv1D)             (None, 151, 32)      12288       ['activation[16][0]']
#
#  conv1d_63 (Conv1D)             (None, 151, 64)      9216        ['activation_63[0][0]']
#
#  conv1d_61 (Conv1D)             (None, 151, 32)      3072        ['activation_60[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 151, 32)     96          ['conv1d_58[0][0]']
#  ormalization)
#
#  batch_normalization_71 (BatchN  (None, 151, 64)     192         ['conv1d_63[0][0]']
#  ormalization)
#
#  batch_normalization_69 (BatchN  (None, 151, 32)     96          ['conv1d_61[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 151, 32)      0           ['batch_normalization_66[0][0]']
#
#  activation_64 (Activation)     (None, 151, 64)      0           ['batch_normalization_71[0][0]']
#
#  activation_62 (Activation)     (None, 151, 32)      0           ['batch_normalization_69[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 151, 128)     0           ['activation_59[0][0]',
#                                                                   'activation_64[0][0]',
#                                                                   'activation_62[0][0]']
#
#  conv1d_64 (Conv1D)             (None, 151, 384)     49152       ['concatenate_8[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 151, 384)    1152        ['conv1d_64[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 151, 384)     0           ['batch_normalization_72[0][0]']
#
#  lambda_8 (Lambda)              (None, 151, 384)     0           ['activation[16][0]',
#                                                                   'activation_65[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 151, 384)    1536        ['lambda_8[0][0]']
#  ormalization)
#
#  conv1d_67 (Conv1D)             (None, 151, 32)      12288       ['activation[18][0]']
#
#  batch_normalization_76 (BatchN  (None, 151, 32)     96          ['conv1d_67[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 151, 32)      0           ['batch_normalization_76[0][0]']
#
#  conv1d_69 (Conv1D)             (None, 151, 48)      4608        ['activation_68[0][0]']
#
#  conv1d_66 (Conv1D)             (None, 151, 32)      12288       ['activation[18][0]']
#
#  batch_normalization_78 (BatchN  (None, 151, 48)     144         ['conv1d_69[0][0]']
#  ormalization)
#
#  batch_normalization_75 (BatchN  (None, 151, 32)     96          ['conv1d_66[0][0]']
#  ormalization)
#  activation_70 (Activation)     (None, 151, 48)      0           ['batch_normalization_78[0][0]']
#
#  activation_67 (Activation)     (None, 151, 32)      0           ['batch_normalization_75[0][0]']
#
#  conv1d_65 (Conv1D)             (None, 151, 32)      12288       ['activation[18][0]']
#
#  conv1d_70 (Conv1D)             (None, 151, 64)      9216        ['activation_70[0][0]']
#
#  conv1d_68 (Conv1D)             (None, 151, 32)      3072        ['activation_67[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 151, 32)     96          ['conv1d_65[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 151, 64)     192         ['conv1d_70[0][0]']
#  ormalization)
#
#  batch_normalization_77 (BatchN  (None, 151, 32)     96          ['conv1d_68[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 151, 32)      0           ['batch_normalization_74[0][0]']
#
#  activation_71 (Activation)     (None, 151, 64)      0           ['batch_normalization_79[0][0]']
#
#  activation_69 (Activation)     (None, 151, 32)      0           ['batch_normalization_77[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 151, 128)     0           ['activation_66[0][0]',
#                                                                   'activation_71[0][0]',
#                                                                   'activation_69[0][0]']
#
#  conv1d_71 (Conv1D)             (None, 151, 384)     49152       ['concatenate_9[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 151, 384)    1152        ['conv1d_71[0][0]']
#  ormalization)
#
#  activation_72 (Activation)     (None, 151, 384)     0           ['batch_normalization_80[0][0]']
#
#  lambda_9 (Lambda)              (None, 151, 384)     0           ['activation[18][0]',
#                                                                   'activation_72[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 151, 384)    1536        ['lambda_9[0][0]']
#  ormalization)
#
#  global_average_pooling1d (Glob  (None, 384)         0           ['activation[19][0]']
#  alAveragePooling1D)
#
#  dropout (Dropout)              (None, 384)          0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1024)         394240      ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 2)            2050        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 1,462,178
# Trainable params: 1,441,250
# Non-trainable params: 20,928
# __________________________________________________________________________________________________

# %%
early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min", patience = 4, verbose=1)
redonplat = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_accuracy", mode="max", patience=3, verbose=2)
callbacks_list = [early, redonplat, tf.keras.callbacks.TensorBoard('logs')]

# %%
hist = model.fit(train_data, train_labels_cat, epochs=100, validation_split=0.20, batch_size=32, callbacks=callbacks_list, shuffle=True)
# Out:
# Epoch 1/100
# 1005/1005 [==============================] - 201s 170ms/step - loss: 0.6424 - accuracy: 0.6441 - val_loss: 0.7017 - val_accuracy: 0.6427 - lr: 0.0010
# Epoch 2/100
# 1005/1005 [==============================] - 180s 180ms/step - loss: 0.5523 - accuracy: 0.7207 - val_loss: 0.8112 - val_accuracy: 0.6514 - lr: 0.0010
# Epoch 3/100
# 1005/1005 [==============================] - 167s 166ms/step - loss: 0.5306 - accuracy: 0.7374 - val_loss: 0.5543 - val_accuracy: 0.7252 - lr: 0.0010
# Epoch 4/100
# 1005/1005 [==============================] - 167s 166ms/step - loss: 0.5144 - accuracy: 0.7490 - val_loss: 0.4874 - val_accuracy: 0.7700 - lr: 0.0010
# Epoch 5/100
# 1005/1005 [==============================] - 170s 169ms/step - loss: 0.5011 - accuracy: 0.7577 - val_loss: 0.5052 - val_accuracy: 0.7581 - lr: 0.0010
# Epoch 6/100
# 1005/1005 [==============================] - 167s 166ms/step - loss: 0.4894 - accuracy: 0.7638 - val_loss: 0.6015 - val_accuracy: 0.7319 - lr: 0.0010
# Epoch 7/100
# 1005/1005 [==============================] - ETA: 0s - loss: 0.4777 - accuracy: 0.7733
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1005/1005 [==============================] - 163s 162ms/step - loss: 0.4777 - accuracy: 0.7733 - val_loss: 0.5118 - val_accuracy: 0.7574 - lr: 0.0010
# Epoch 8/100
# 1005/1005 [==============================] - 163s 162ms/step - loss: 0.4227 - accuracy: 0.8080 - val_loss: 0.4531 - val_accuracy: 0.7864 - lr: 1.0000e-04
# Epoch 9/100
# 1005/1005 [==============================] - 166s 165ms/step - loss: 0.3949 - accuracy: 0.8232 - val_loss: 0.4545 - val_accuracy: 0.7872 - lr: 1.0000e-04
# Epoch 10/100
# 1005/1005 [==============================] - 166s 165ms/step - loss: 0.3724 - accuracy: 0.8361 - val_loss: 0.4739 - val_accuracy: 0.7836 - lr: 1.0000e-04
# Epoch 11/100
# 1005/1005 [==============================] - 162s 162ms/step - loss: 0.3477 - accuracy: 0.8481 - val_loss: 0.4763 - val_accuracy: 0.7842 - lr: 1.0000e-04
# Epoch 12/100
# 1005/1005 [==============================] - ETA: 0s - loss: 0.3224 - accuracy: 0.8616
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1005/1005 [==============================] - 138s 137ms/step - loss: 0.3224 - accuracy: 0.8616 - val_loss: 0.5065 - val_accuracy: 0.7744 - lr: 1.0000e-04
# Epoch 12: early stopping

# %%
pred_test = np.argmax(model.predict(test_data), axis = 1)
accuracy = accuracy_score(test_labels, pred_test)
print("Testing Accuracy: ", accuracy)
# Out:
# Testing Accuracy:  0.7832536837913182

# %%
cf_m = tf.math.confusion_matrix(test_labels, pred_test, num_classes=2)
print(cf_m)
# Out:
# tf.Tensor(
# [[4109  841]
#  [1336 3758]], shape=(2, 2), dtype=int32)

# %%
recall = precision_recall_fscore_support(test_labels, pred_test, average="binary")
print('Precision: {0:0.2f}'.format(recall[0]))
print('Recall: {0:1.2f}'.format(recall[1]))
print('F1-Score: {0:2.2f}'.format(recall[2]))
# Out:
# Precision: 0.82
# Recall: 0.74
# F1-Score: 0.78

# %%
pred_test = np.argmax(model.predict(test_data), axis = 1)
pred_test = to_categorical(pred_test)
ns_auc = roc_auc_score(test_labels_cat[:, 0], pred_test[:, 0])
lr_auc = roc_auc_score(test_labels_cat[:, 1], pred_test[:, 1])
print('Non-Promoter: ROC AUC=%.3f' % (ns_auc))
print('Promoter: ROC AUC=%.3f' % (lr_auc))
ns_fpr, ns_tpr, _ = roc_curve(test_labels_cat[:, 0], pred_test[:, 0])
lr_fpr, lr_tpr, _ = roc_curve(test_labels_cat[:, 1], pred_test[:, 1])
# Out:
# Non-Promoter: ROC AUC=0.784
# Promoter: ROC AUC=0.784

# %%
fig = plt.figure(figsize=(25, 20))
plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Non-Promoter', linewidth=4)
plt.plot(lr_fpr, lr_tpr, marker='.', label='Promoter', linewidth=4)
plt.xlabel('False Positive Rate', fontsize=fontsize)
plt.ylabel('True Positive Rate', fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.legend(fontsize=fontsize)
plt.savefig("roc_inception.png")

# %%
summ = hist.history

epochs = [i for i in range(1, len(summ['loss'])+1)]

fig = plt.figure(figsize=(25, 20))
plt.plot(epochs, summ['loss'], color='blue', label="training_loss", linewidth=4)
plt.plot(epochs, summ['val_loss'], color='red', label="validation_loss", linewidth=4)
plt.legend(loc='best', fontsize=fontsize)
plt.title('Loss vs Epoch', fontsize=fontsize)
plt.ylabel('Loss', fontsize=fontsize)
plt.xlabel('Epoch', fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
# plt.show()
plt.savefig("loss_inception.png")

fig = plt.figure(figsize=(25, 20))
plt.plot(epochs, summ['accuracy'], color='blue', label="training_accuracy", linewidth=4)
plt.plot(epochs, summ['val_accuracy'], color='red',label="validation_accuracy", linewidth=4)
plt.legend(loc='best', fontsize=fontsize)
plt.title('Accuracy vs Epoch', fontsize=fontsize)
plt.ylabel('Accuracy', fontsize=fontsize)
plt.xlabel('Epoch', fontsize=fontsize)
# plt.show()
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.savefig("accuracy_inception.png")
